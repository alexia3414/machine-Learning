# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib pyplt as plt
from sklearn.model_select import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import*
from sklearn.preprocessing import standard_scaller
from joblib import Dump
# Out:
#   Cell In[56], line 4
#     import matplotlib pyplt as plt
#                       ^
# SyntaxError: invalid syntax

# %%
df=pd.read_csv("examen.csv")
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
ex_dset=df[['horsepower','curb-weight','engine-size','highway-mpg','car-price']]
ex_dset
# Out:
#     horsepower  curb-weight  engine-size  highway-mpg car-price
# 0          111         2548          130           27     13495
# 1          111         2548          130           27     16500
# 2          154         2823          152           26     16500
# 3          102         2337          109           30     13950
# 4          115         2824          136           22     17450
# ..         ...          ...          ...          ...       ...
# 200        114         2952          141           28     16845
# 201        160         3049          141           25     19045
# 202        134         3012          173           23     21485
# 203        106         3217          145           27     22470
# 204        114         3062          141           25     22625
#
# [205 rows x 5 columns]

# %%
df=ex_dset.dtypes()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2328\2071825828.py in ?()
# ----> 1 df=ex_dset.Dtypes()
#
# C:\Program Files\anaconda\1\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Dtypes'

# %%
x=ex_dset.illoc[:,-1].values
y=ex_dset.illoc[:,1].values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2328\908011939.py in ?()
# ----> 1 x=ex_dset.illoc[:,-1].values
#       2 y=ex_dset.illoc[:,1].values
#
# C:\Program Files\anaconda\1\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'illoc'

# %%
ex_dset=ex_dset.replace("?",np.nan)
ex_dset["car-price"]=pd.to_numeric(cat_dset["car-price"],errors="coerce")
ex_dset["horsepower"]=pd.to_numeric(cat_dset["horsepower"],errors="coerce")
ex_dset=isnull().sum
ex_dset["horcepower"].fillna(cat_dset["car-price"].mean(),inplace=True)
ex_dset["car-price"].fillna(cat_dset["horcepower"].mean(),inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 2
#       1 ex_dset=ex_dset.replace("?",np.nan)
# ----> 2 ex_dset["car-price"]=pd.to_numeric(cat_dset["car-price"],errors="coerce")
#       3 ex_dset["horsepower"]=pd.to_numeric(cat_dset["horsepower"],errors="coerce")
#       4 ex_dset=isnull().sum
#
# NameError: name 'cat_dset' is not defined

# %%
x=x_train, x_test, y_train, y_test,y_train=('testsize=0,5','random_state=50')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 x=x_train, x_test, y_train, y_test,y_train=('testsize=0,5','random_state=50')
#
# ValueError: not enough values to unpack (expected 5, got 2)

# %%
y=y_train, y_test, y_test=('train_model=205','model_test=209')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 y=y_train, y_test, y_test=('train_model=205','model_test=209')
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
mse=mean_square(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 mse=mean_square(y_test,y_pred)
#
# NameError: name 'mean_square' is not defined

# %%
r2=r2_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 r2=r2_score(y_test,y_pred)
#
# NameError: name 'y_test' is not defined

# %%
lm=LinearRegression()
lm
# Out:
# LinearRegression()

# %%
Dump(lm"examen")
# Out:
#   Cell In[67], line 1
#     Dump(lm"examen")
#            ^
# SyntaxError: invalid syntax
